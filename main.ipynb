# %%
# !python fit_data.py --type 'vox' --device 'cpu' --max_iter 50000
# Out:
#  category   #instances
# ----------  ------------
#   chair     61000
#   total     61000
# /Users/tsaiiast/Desktop/MSCV/Learning3d/assignment2/r2n2_custom.py:207: UserWarning: The following categories are included in R2N2'sofficial mapping but not found in the dataset location ./r2n2_shapenet_dataset/shapenet: 04256520, 02933112, 02828884, 03211117, 04090263, 03691459, 03636649, 04401088, 02691156, 04379243, 02958343, 04530566
#   warnings.warn(msg)
# /Users/tsaiiast/miniconda3/envs/3d/lib/python3.12/site-packages/pytorch3d/datasets/r2n2/utils.py:182: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   storage = torch.ByteStorage.from_buffer(f.read())
# [   0/ 500]; ttime: 1 (0.02); loss: 0.964
# [   1/ 500]; ttime: 1 (0.00); loss: 0.964
# ...

# %%
# !python fit_data.py --type 'point' --device 'cpu' --max_iter 50000
# Out:
#  category   #instances
# ----------  ------------
#   chair     61000
#   total     61000
# /Users/tsaiiast/Desktop/MSCV/Learning3d/assignment2/r2n2_custom.py:207: UserWarning: The following categories are included in R2N2'sofficial mapping but not found in the dataset location ./r2n2_shapenet_dataset/shapenet: 04256520, 02933112, 02828884, 03211117, 04090263, 03691459, 03636649, 04401088, 02691156, 04379243, 02958343, 04530566
#   warnings.warn(msg)
# /Users/tsaiiast/miniconda3/envs/3d/lib/python3.12/site-packages/pytorch3d/datasets/r2n2/utils.py:182: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   storage = torch.ByteStorage.from_buffer(f.read())
# ...

# %%
# !python fit_data.py --type 'mesh' --device 'cpu' --max_iter 100
# Out:
#  category   #instances
# ----------  ------------
#   chair     61000
#   total     61000
# /Users/tsaiiast/Desktop/MSCV/Learning3d/assignment2/r2n2_custom.py:207: UserWarning: The following categories are included in R2N2'sofficial mapping but not found in the dataset location ./r2n2_shapenet_dataset/shapenet: 04256520, 02933112, 02828884, 03211117, 04090263, 03691459, 03636649, 04401088, 02691156, 04379243, 02958343, 04530566
#   warnings.warn(msg)
# /Users/tsaiiast/miniconda3/envs/3d/lib/python3.12/site-packages/pytorch3d/datasets/r2n2/utils.py:182: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   storage = torch.ByteStorage.from_buffer(f.read())
# Starting training !
# ...
